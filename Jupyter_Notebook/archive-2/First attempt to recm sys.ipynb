# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/owais/Jupyter Notebook/archive-2/rating.csv')

# %%
df.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
df2 = pd.read_csv('/Users/owais/Jupyter Notebook/archive-2/anime.csv')

# %%
df2
# Out:
#        anime_id                                               name
# 0         32281                                     Kimi no Na wa.  \
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes
# 0                   Drama, Romance, School, Supernatural  Movie        1  \
# ...

# %%
vals = [696,44,120,31047,5114]
df2[df2['anime_id'].isin(vals)]
# Out:
#       anime_id                                               name
# 1         5114                   Fullmetal Alchemist: Brotherhood  \
# 21          44  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...
# 849        120                                      Fruits Basket
# 1458       696                                      Tenchi Muyou!
#
#                                                   genre type episodes  rating
# 1     Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64    9.26  \
# 21    Action, Drama, Historical, Martial Arts, Roman...  OVA        4    8.83
# 849   Comedy, Drama, Fantasy, Romance, Shoujo, Slice...   TV       26    7.80
# 1458     Comedy, Harem, Romance, Sci-Fi, Shounen, Space   TV       26    7.54
#
#       members
# 1      793665
# 21     129307
# 849    242553
# 1458    38372

# %%
df2.loc[df2['genre'] == 'Hentai']
# Out:
#        anime_id                                               name   genre
# 11114     11879                                Oni Chichi: Re-born  Hentai  \
# 11115     29575                                 Mankitsu Happening  Hentai
# 11116     15843                       Koiito Kinenbi The Animation  Hentai
# 11117     21097                                Oni Chichi: Rebuild  Hentai
# 11119     10779                Eroge! H mo Game mo Kaihatsu Zanmai  Hentai
# ...         ...                                                ...     ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami  Hentai
# 12290      5543                                        Under World  Hentai
# 12291      5621                     Violence Gekiga David no Hoshi  Hentai
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...  Hentai
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!  Hentai
#
#         type episodes  rating  members
# ...

# %%
df.isna().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
df.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
x=df['anime_id'].sort_values().unique()

# %%
print(x)
# Out:
# [    1     5     6 ... 34475 34476 34519]

# %%
len(x)
# Out:
# 11200

# %%
df['anime_id'].value_counts()
# Out:
# anime_id
# 1535     39340
# 11757    30583
# 16498    29584
# 1575     27718
# 226      27506
#          ...
# 12781        1
# 12767        1
# 12765        1
# 12763        1
# 30738        1
# Name: count, Length: 11200, dtype: int64

# %%
df2.loc[df2['anime_id']==1535]
# Out:
#     anime_id        name                                              genre
# 40      1535  Death Note  Mystery, Police, Psychological, Supernatural, ...  \
#
#    type episodes  rating  members
# 40   TV       37    8.71  1013917

# %%
df2.loc[df2['anime_id']==226]
# Out:
#      anime_id        name                                              genre
# 760       226  Elfen Lied  Action, Drama, Horror, Psychological, Romance,...  \
#
#     type episodes  rating  members
# 760   TV       13    7.85   623511

# %%
df3=pd.DataFrame(df["anime_id"].value_counts())

# %%
df3.describe().T
# Out:
#          count        mean          std  min  25%   50%     75%      max
# count  11200.0  697.655089  2028.627749  1.0  5.0  51.5  385.25  39340.0

# %%
df3[df3['count']>1000]
# Out:
#           count
# anime_id
# 1535      39340
# 11757     30583
# 16498     29584
# 1575      27718
# 226       27506
# ...         ...
# 16910      1007
# 4447       1006
# 2171       1005
# 2424       1005
# 2031       1004
#
# [1720 rows x 1 columns]

# %%
df3.loc[df3['count']==3300]
# Out:
#           count
# anime_id
# 3229       3300
# 6030       3300

# %%
df2[df2['anime_id']==15]
# Out:
#      anime_id          name                            genre type episodes
# 433        15  Eyeshield 21  Action, Comedy, Shounen, Sports   TV      145  \
#
#      rating  members
# 433    8.08    83648

# %%
df
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [7813737 rows x 3 columns]

# %%
df2[df2['anime_id']==17187]
# Out:
#       anime_id                                             name
# 1181     17187  Ghost in the Shell: Arise - Border:1 Ghost Pain  \
#
#                                      genre   type episodes  rating  members
# 1181  Mecha, Police, Psychological, Sci-Fi  Movie        1    7.64    31747

# %%
rare_movies = df3[df3["count"] <= 1000].index
common_movie = df[~df["anime_id"].isin(rare_movies)]

# %%
len(common_movie['anime_id'].unique())
# Out:
# 1720

# %%
pivot_table = common_movie.pivot_table(index = "user_id", columns = "anime_id")

# %%
pivot_table
# Out:
#          rating                                                        ...
# anime_id  1     5     6     7     15    16    18    19    20    22     ...
# user_id                                                                ...
# 1           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  -1.0   NaN  ...  \
# 2           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   8.0   NaN  ...
# 4           NaN   NaN  -1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5           NaN   NaN   8.0   NaN   6.0   NaN   6.0   NaN   6.0   5.0  ...
# ...         ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 73512       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 73513       9.0   8.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 73514       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
pivot_table=pivot_table.replace(np.nan, 0)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarity between users
user_similarity_matrix = cosine_similarity(pivot_table)
