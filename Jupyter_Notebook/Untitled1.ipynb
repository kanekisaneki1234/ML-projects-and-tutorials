# %% [markdown]
# # Webscraping wikipedia for html tables venture 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
url = "https://en.wikipedia.org/wiki/2015_in_anime"

response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    html_content = response.text
else:
    print('Failed to retrieve the web page.')

# %%
tables = pd.read_html(html_content)

df = {}

# Check if any tables were found on the web page
if tables:
    df = tables[1]
    
else:
    print("No tables found on the web page.")

# %%
df
# Out:
#     Release Date                                              Title
# 0      January 9                             Psycho-Pass: The Movie  \
# 1     January 31               Arpeggio of Blue Steel -Ars Nova DC-
# 2    February 20                           The Case of Hana & Alice
# 3        March 6                                 Knights of Sidonia
# 4        March 7                    Doraemon: Nobita's Space Heroes
# 5        March 7  PriPara the Movie: Eeeeveryone, Assemble! Pris...
# 6       March 13                              Shimajirō to Ōkina Ki
# 7       March 14           Beyond the Boundary: I'll Be Here – Past
# 8       March 14            Pretty Cure All Stars: Spring Carnival♪
# 9        April 5   Tamayura: Sotsugyō Shashin Dai-1-bu Me -Kizashi-
# 10      April 12                        Le Labyrinthe de la Grisaia
# 11      April 18             Detective Conan: Sunflowers of Inferno
# 12      April 18  Crayon Shin-Chan: My Moving Story! Cactus Larg...
# ...

# %%
len(tables)
# Out:
# 7

# %%
df1 = tables[2]
df2 = tables[3]
df3 = tables[4]
df4 = tables[5]
df5 = tables[6]

# %%
df1
# Out:
#     First Run Start and End Dates                                Title   Eps
# 0            January 4 – March 22                         Absolute Duo  12.0  \
# 1            January 4 – March 29     Minna Atsumare! Falcom Gakuen SC  13.0
# 2            January 4 – March 28        Tantei Kageki Milky Holmes TD  12.0
# 3            January 5 – March 30                       Kamisama Kiss◎  12.0
# 4            January 5 – March 31                      Yurikuma Arashi  12.0
# ..                            ...                                  ...   ...
# 158      October 10 – December 26  Seraph of the End: Battle in Nagoya  12.0
# 159      October 10 – December 26              Valkyrie Drive: Mermaid  12.0
# 160   October 11 – March 27, 2016                          Brave Beats  22.0
# 161   October 11 – April 10, 2016  Cardfight!! Vanguard G: GIRS Crisis  26.0
# 162      October 12 – December 28                         Ani Tore! EX  12.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Release Date            40 non-null     object
#  1   Title                   40 non-null     object
#  2   Studio                  40 non-null     object
#  3   Director                37 non-null     object
#  4   Running Time (minutes)  9 non-null      float64
#  5   Notes                   29 non-null     object
#  6   Ref                     37 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 2.3+ KB

# %%
df
# Out:
#     Release Date                                              Title
# 0      January 9                             Psycho-Pass: The Movie  \
# 1     January 31               Arpeggio of Blue Steel -Ars Nova DC-
# 2    February 20                           The Case of Hana & Alice
# 3        March 6                                 Knights of Sidonia
# 4        March 7                    Doraemon: Nobita's Space Heroes
# 5        March 7  PriPara the Movie: Eeeeveryone, Assemble! Pris...
# 6       March 13                              Shimajirō to Ōkina Ki
# 7       March 14           Beyond the Boundary: I'll Be Here – Past
# 8       March 14            Pretty Cure All Stars: Spring Carnival♪
# 9        April 5   Tamayura: Sotsugyō Shashin Dai-1-bu Me -Kizashi-
# 10      April 12                        Le Labyrinthe de la Grisaia
# 11      April 18             Detective Conan: Sunflowers of Inferno
# 12      April 18  Crayon Shin-Chan: My Moving Story! Cactus Larg...
# ...

# %%
df.drop(["Running Time (minutes)","Notes","Ref"], axis=1, inplace=True)

# %%
df.head()
# Out:
#   Release Date                                 Title             Studio
# 0    January 9                Psycho-Pass: The Movie     Production I.G  \
# 1   January 31  Arpeggio of Blue Steel -Ars Nova DC-           Sanzigen
# 2  February 20              The Case of Hana & Alice    Steve N' Steven
# 3      March 6                    Knights of Sidonia   Polygon Pictures
# 4      March 7       Doraemon: Nobita's Space Heroes  Shin-Ei Animation
#
#             Director
# 0  Naoyoshi Shiotani
# 1        Seiji Kishi
# 2        Shunji Iwai
# 3      Kobun Shizuno
# 4    Yoshihiro Osugi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Release Date  40 non-null     object
#  1   Title         40 non-null     object
#  2   Studio        40 non-null     object
#  3   Director      37 non-null     object
# dtypes: object(4)
# memory usage: 1.4+ KB

# %%
df.isna()
# Out:
#     Release Date  Title  Studio  Director
# 0          False  False   False     False
# 1          False  False   False     False
# 2          False  False   False     False
# 3          False  False   False     False
# 4          False  False   False     False
# 5          False  False   False     False
# 6          False  False   False     False
# 7          False  False   False     False
# 8          False  False   False      True
# 9          False  False   False     False
# 10         False  False   False     False
# 11         False  False   False     False
# 12         False  False   False     False
# 13         False  False   False     False
# 14         False  False   False     False
# 15         False  False   False     False
# 16         False  False   False     False
# 17         False  False   False     False
# 18         False  False   False     False
# 19         False  False   False     False
# 20         False  False   False     False
# ...

# %%
nan_mask_beta = df.isnull()

# Use the boolean mask with iloc to locate NaN values
nan_values_beta = df[df[nan_mask_beta]]

# %%
nan_values_beta
# failed attempt
# Out:
#    Release Date Title Studio Director
# 0           NaN   NaN    NaN      NaN
# 1           NaN   NaN    NaN      NaN
# 2           NaN   NaN    NaN      NaN
# 3           NaN   NaN    NaN      NaN
# 4           NaN   NaN    NaN      NaN
# 5           NaN   NaN    NaN      NaN
# 6           NaN   NaN    NaN      NaN
# 7           NaN   NaN    NaN      NaN
# 8           NaN   NaN    NaN      NaN
# 9           NaN   NaN    NaN      NaN
# 10          NaN   NaN    NaN      NaN
# 11          NaN   NaN    NaN      NaN
# 12          NaN   NaN    NaN      NaN
# 13          NaN   NaN    NaN      NaN
# 14          NaN   NaN    NaN      NaN
# 15          NaN   NaN    NaN      NaN
# 16          NaN   NaN    NaN      NaN
# 17          NaN   NaN    NaN      NaN
# 18          NaN   NaN    NaN      NaN
# 19          NaN   NaN    NaN      NaN
# 20          NaN   NaN    NaN      NaN
# 21          NaN   NaN    NaN      NaN
# 22          NaN   NaN    NaN      NaN
# 23          NaN   NaN    NaN      NaN
# ...

# %%
nan_mask = df.isnull().any(axis=1)

# Use the boolean mask with iloc to locate rows with NaN values
nan_rows = df[nan_mask]

# %%
nan_rows
# Out:
#     Release Date                                     Title          Studio
# 8       March 14   Pretty Cure All Stars: Spring Carnival♪  Toei Animation  \
# 23        July 3  Haikyu!! the Movie: Ending and Beginning  Production I.G
# 33  September 18    Haikyu!! the Movie: Winners and Losers  Production I.G
#
#    Director
# 8       NaN
# 23      NaN
# 33      NaN

# %%
nan_mask = df.isnull().any(axis=0)

# Use the boolean mask with loc to locate columns with NaN values
nan_columns = df.loc[:, nan_mask]

# %%
nan_mask # for axis=0
# Out:
# Release Date    False
# Title           False
# Studio          False
# Director         True
# dtype: bool

# %%
nan_mask # for axis = 1
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33     True
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# dtype: bool

# %%
df.drop([8,23,33], axis=0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 0 to 39
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Release Date  37 non-null     object
#  1   Title         37 non-null     object
#  2   Studio        37 non-null     object
#  3   Director      37 non-null     object
# dtypes: object(4)
# memory usage: 1.4+ KB

# %%
df.reset_index() # creates a new column with old indices
# Out:
#     index  Release Date                                              Title
# 0       0     January 9                             Psycho-Pass: The Movie  \
# 1       1    January 31               Arpeggio of Blue Steel -Ars Nova DC-
# 2       2   February 20                           The Case of Hana & Alice
# 3       3       March 6                                 Knights of Sidonia
# 4       4       March 7                    Doraemon: Nobita's Space Heroes
# 5       5       March 7  PriPara the Movie: Eeeeveryone, Assemble! Pris...
# 6       6      March 13                              Shimajirō to Ōkina Ki
# 7       7      March 14           Beyond the Boundary: I'll Be Here – Past
# 8       9       April 5   Tamayura: Sotsugyō Shashin Dai-1-bu Me -Kizashi-
# 9      10      April 12                        Le Labyrinthe de la Grisaia
# 10     11      April 18             Detective Conan: Sunflowers of Inferno
# ...

# %%
df_cleaned = df.reset_index(drop = True) # this avoids creating the column for the old indices

# %%
df_cleaned
# Out:
#     Release Date                                              Title
# 0      January 9                             Psycho-Pass: The Movie  \
# 1     January 31               Arpeggio of Blue Steel -Ars Nova DC-
# 2    February 20                           The Case of Hana & Alice
# 3        March 6                                 Knights of Sidonia
# 4        March 7                    Doraemon: Nobita's Space Heroes
# 5        March 7  PriPara the Movie: Eeeeveryone, Assemble! Pris...
# 6       March 13                              Shimajirō to Ōkina Ki
# 7       March 14           Beyond the Boundary: I'll Be Here – Past
# 8        April 5   Tamayura: Sotsugyō Shashin Dai-1-bu Me -Kizashi-
# 9       April 12                        Le Labyrinthe de la Grisaia
# 10      April 18             Detective Conan: Sunflowers of Inferno
# 11      April 18  Crayon Shin-Chan: My Moving Story! Cactus Larg...
# 12      April 18                    Dragon Ball Z: Resurrection 'F'
# ...

# %%
df1
# Out:
#     First Run Start and End Dates                                Title   Eps
# 0            January 4 – March 22                         Absolute Duo  12.0  \
# 1            January 4 – March 29     Minna Atsumare! Falcom Gakuen SC  13.0
# 2            January 4 – March 28        Tantei Kageki Milky Holmes TD  12.0
# 3            January 5 – March 30                       Kamisama Kiss◎  12.0
# 4            January 5 – March 31                      Yurikuma Arashi  12.0
# ..                            ...                                  ...   ...
# 158      October 10 – December 26  Seraph of the End: Battle in Nagoya  12.0
# 159      October 10 – December 26              Valkyrie Drive: Mermaid  12.0
# 160   October 11 – March 27, 2016                          Brave Beats  22.0
# 161   October 11 – April 10, 2016  Cardfight!! Vanguard G: GIRS Crisis  26.0
# 162      October 12 – December 28                         Ani Tore! EX  12.0
#
# ...

# %%
year = 2015
date_strings = ['October 29', 'November 15', 'December 5']

# Convert to datetime with the specified year
date_series = pd.to_datetime([f"{month} {day}, {year}" for month, day in map(lambda x: x.split(), date_strings)])
# df['DateColumn'] = df['DateColumn'].str.split(' ').apply(lambda x: f"{x[1]}-{month_mapping[x[0]]}-{pd.Timestamp.now().year}")
print(date_series)
# Out:
# DatetimeIndex(['2015-10-29', '2015-11-15', '2015-12-05'], dtype='datetime64[ns]', freq=None)

# %%
type(date_series)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
dates = df_cleaned['Release Date'].to_numpy()

# %%
dates
# Out:
# array(['January 9', 'January 31', 'February 20', 'March 6', 'March 7',
#        'March 7', 'March 13', 'March 14', 'April 5', 'April 12',
#        'April 18', 'April 18', 'April 18', 'April 25', 'May 9', 'May 23',
#        'May 23', 'June 5', 'June 12', 'June 13', 'June 20', 'June 25',
#        'July 4', 'July 11', 'July 18', 'July 18', 'August 28',
#        'August 22', 'August 22', 'August 29', 'September 19', 'October 2',
#        'October 3', 'November 13', 'November 21', 'November 28',
#        'December 23'], dtype=object)

# %%
date_series = pd.to_datetime([f"{month} {day}, {year}" for month, day in map(lambda x: x.split(), dates)])

# %%
date_series
# Out:
# DatetimeIndex(['2015-01-09', '2015-01-31', '2015-02-20', '2015-03-06',
#                '2015-03-07', '2015-03-07', '2015-03-13', '2015-03-14',
#                '2015-04-05', '2015-04-12', '2015-04-18', '2015-04-18',
#                '2015-04-18', '2015-04-25', '2015-05-09', '2015-05-23',
#                '2015-05-23', '2015-06-05', '2015-06-12', '2015-06-13',
#                '2015-06-20', '2015-06-25', '2015-07-04', '2015-07-11',
#                '2015-07-18', '2015-07-18', '2015-08-28', '2015-08-22',
#                '2015-08-22', '2015-08-29', '2015-09-19', '2015-10-02',
#                '2015-10-03', '2015-11-13', '2015-11-21', '2015-11-28',
#                '2015-12-23'],
#               dtype='datetime64[ns]', freq=None)

# %%
df_cleaned['Release Date'] = date_series

# %%
df_cleaned['Release Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 37 entries, 0 to 36
# Series name: Release Date
# Non-Null Count  Dtype
# --------------  -----
# 37 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 424.0 bytes

# %%
df_cleaned
# Out:
#    Release Date                                              Title
# 0    2015-01-09                             Psycho-Pass: The Movie  \
# 1    2015-01-31               Arpeggio of Blue Steel -Ars Nova DC-
# 2    2015-02-20                           The Case of Hana & Alice
# 3    2015-03-06                                 Knights of Sidonia
# 4    2015-03-07                    Doraemon: Nobita's Space Heroes
# 5    2015-03-07  PriPara the Movie: Eeeeveryone, Assemble! Pris...
# 6    2015-03-13                              Shimajirō to Ōkina Ki
# 7    2015-03-14           Beyond the Boundary: I'll Be Here – Past
# 8    2015-04-05   Tamayura: Sotsugyō Shashin Dai-1-bu Me -Kizashi-
# 9    2015-04-12                        Le Labyrinthe de la Grisaia
# 10   2015-04-18             Detective Conan: Sunflowers of Inferno
# 11   2015-04-18  Crayon Shin-Chan: My Moving Story! Cactus Larg...
# 12   2015-04-18                    Dragon Ball Z: Resurrection 'F'
# ...

# %%
# df_cleaned['Release Date'] = pd.to_datetime(df_cleaned['Release Date'])

# %%
# df_cleaned
# Out:
#    Release Date                                              Title
# 0    2023-01-09                             Psycho-Pass: The Movie  \
# 1    2023-01-31               Arpeggio of Blue Steel -Ars Nova DC-
# 2    2023-02-20                           The Case of Hana & Alice
# 3    2023-03-06                                 Knights of Sidonia
# 4    2023-03-07                    Doraemon: Nobita's Space Heroes
# 5    2023-03-07  PriPara the Movie: Eeeeveryone, Assemble! Pris...
# 6    2023-03-13                              Shimajirō to Ōkina Ki
# 7    2023-03-14           Beyond the Boundary: I'll Be Here – Past
# 8    2023-04-05   Tamayura: Sotsugyō Shashin Dai-1-bu Me -Kizashi-
# 9    2023-04-12                        Le Labyrinthe de la Grisaia
# 10   2023-04-18             Detective Conan: Sunflowers of Inferno
# 11   2023-04-18  Crayon Shin-Chan: My Moving Story! Cactus Larg...
# 12   2023-04-18                    Dragon Ball Z: Resurrection 'F'
# ...

# %%
df_cleaned['Release Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 37 entries, 0 to 36
# Series name: Release Date
# Non-Null Count  Dtype
# --------------  -----
# 37 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 424.0 bytes

# %%
def dateconverter(dataframe, column):
    dates = dataframe[column].to_numpy()
    date_series = pd.to_datetime([f"{month} {day}, {year}" for month, day in map(lambda x: x.split(), dates)])
    dataframe[column] = date_series

############# Make sure to input column name as string like "Release Date" #################


# def dateconverter2(dataframe, column_index, column_name):
#     dates = dataframe.iloc[:,column_index].to_numpy()
#     date_series = np.array(pd.to_datetime([f"{month} {day}, {year}" for month, day in map(lambda x: x.split(), dates)]))
#     dataframe[column_name] = date_series
    
# def dateconverter2(dataframe, column_index, column_name):
#     dates = dataframe.iloc[:,column_index].to_numpy()
#     date_series = (pd.to_datetime([f"{month} {day}, {year}" for month, day in map(lambda x: x.split(), dates)]))
#     dataframe[column_name] = date_series
    
# def dateconverter(dataframe, column):
#     dates = dataframe[column].to_numpy()
#     date_series = np.array(pd.to_datetime([f"{month} {day}, {year}" for month, day in map(lambda x: x.split(), dates)]))
#     dataframe[column] = date_series

# %%
df.iloc[:,0]
# Out:
# 0        January 9
# 1       January 31
# 2      February 20
# 3          March 6
# 4          March 7
# 5          March 7
# 6         March 13
# 7         March 14
# 9          April 5
# 10        April 12
# 11        April 18
# 12        April 18
# 13        April 18
# 14        April 25
# 15           May 9
# 16          May 23
# 17          May 23
# 18          June 5
# 19         June 12
# 20         June 13
# 21         June 20
# 22         June 25
# 24          July 4
# 25         July 11
# 26         July 18
# 27         July 18
# 28       August 28
# 29       August 22
# 30       August 22
# 31       August 29
# 32    September 19
# 34       October 2
# 35       October 3
# 36     November 13
# 37     November 21
# 38     November 28
# 39     December 23
# Name: Release Date, dtype: object

# %%
dateconverter(df_cleaned, "Release Date")

# %%
df_cleaned
# Out:
#    Release Date                                              Title
# 0    2015-01-09                             Psycho-Pass: The Movie  \
# 1    2015-01-31               Arpeggio of Blue Steel -Ars Nova DC-
# 2    2015-02-20                           The Case of Hana & Alice
# 3    2015-03-06                                 Knights of Sidonia
# 4    2015-03-07                    Doraemon: Nobita's Space Heroes
# 5    2015-03-07  PriPara the Movie: Eeeeveryone, Assemble! Pris...
# 6    2015-03-13                              Shimajirō to Ōkina Ki
# 7    2015-03-14           Beyond the Boundary: I'll Be Here – Past
# 8    2015-04-05   Tamayura: Sotsugyō Shashin Dai-1-bu Me -Kizashi-
# 9    2015-04-12                        Le Labyrinthe de la Grisaia
# 10   2015-04-18             Detective Conan: Sunflowers of Inferno
# 11   2015-04-18  Crayon Shin-Chan: My Moving Story! Cactus Larg...
# 12   2015-04-18                    Dragon Ball Z: Resurrection 'F'
# ...

# %%
df = tables[1]

# %%
df
# Out:
#    Release Date                                              Title
# 0    2015-01-09                             Psycho-Pass: The Movie  \
# 1    2015-01-31               Arpeggio of Blue Steel -Ars Nova DC-
# 2    2015-02-20                           The Case of Hana & Alice
# 3    2015-03-06                                 Knights of Sidonia
# 4    2015-03-07                    Doraemon: Nobita's Space Heroes
# 5    2015-03-07  PriPara the Movie: Eeeeveryone, Assemble! Pris...
# 6    2015-03-13                              Shimajirō to Ōkina Ki
# 7    2015-03-14           Beyond the Boundary: I'll Be Here – Past
# 9    2015-04-05   Tamayura: Sotsugyō Shashin Dai-1-bu Me -Kizashi-
# 10   2015-04-12                        Le Labyrinthe de la Grisaia
# 11   2015-04-18             Detective Conan: Sunflowers of Inferno
# 12   2015-04-18  Crayon Shin-Chan: My Moving Story! Cactus Larg...
# 13   2015-04-18                    Dragon Ball Z: Resurrection 'F'
# ...

# %%
df_cleaned['Release Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 37 entries, 0 to 36
# Series name: Release Date
# Non-Null Count  Dtype
# --------------  -----
# 37 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 424.0 bytes

# %%
df
# Out:
#     Release Date                                              Title
# 0      January 9                             Psycho-Pass: The Movie  \
# 1     January 31               Arpeggio of Blue Steel -Ars Nova DC-
# 2    February 20                           The Case of Hana & Alice
# 3        March 6                                 Knights of Sidonia
# 4        March 7                    Doraemon: Nobita's Space Heroes
# 5        March 7  PriPara the Movie: Eeeeveryone, Assemble! Pris...
# 6       March 13                              Shimajirō to Ōkina Ki
# 7       March 14           Beyond the Boundary: I'll Be Here – Past
# 9        April 5   Tamayura: Sotsugyō Shashin Dai-1-bu Me -Kizashi-
# 10      April 12                        Le Labyrinthe de la Grisaia
# 11      April 18             Detective Conan: Sunflowers of Inferno
# 12      April 18  Crayon Shin-Chan: My Moving Story! Cactus Larg...
# 13      April 18                    Dragon Ball Z: Resurrection 'F'
# ...

# %%
gates = df.iloc[:,0].to_numpy()

# %%
print(len(gates),"\n")
print("\n",gates)
# Out:
# 37
#
#
#  ['January 9' 'January 31' 'February 20' 'March 6' 'March 7' 'March 7'
#  'March 13' 'March 14' 'April 5' 'April 12' 'April 18' 'April 18'
#  'April 18' 'April 25' 'May 9' 'May 23' 'May 23' 'June 5' 'June 12'
#  'June 13' 'June 20' 'June 25' 'July 4' 'July 11' 'July 18' 'July 18'
#  'August 28' 'August 22' 'August 22' 'August 29' 'September 19'
#  'October 2' 'October 3' 'November 13' 'November 21' 'November 28'
#  'December 23']

# %%
test = df.reset_index(drop=True)

# %%
test
# Out:
#     Release Date                                              Title
# 0      January 9                             Psycho-Pass: The Movie  \
# 1     January 31               Arpeggio of Blue Steel -Ars Nova DC-
# 2    February 20                           The Case of Hana & Alice
# 3        March 6                                 Knights of Sidonia
# 4        March 7                    Doraemon: Nobita's Space Heroes
# 5        March 7  PriPara the Movie: Eeeeveryone, Assemble! Pris...
# 6       March 13                              Shimajirō to Ōkina Ki
# 7       March 14           Beyond the Boundary: I'll Be Here – Past
# 8        April 5   Tamayura: Sotsugyō Shashin Dai-1-bu Me -Kizashi-
# 9       April 12                        Le Labyrinthe de la Grisaia
# 10      April 18             Detective Conan: Sunflowers of Inferno
# 11      April 18  Crayon Shin-Chan: My Moving Story! Cactus Larg...
# 12      April 18                    Dragon Ball Z: Resurrection 'F'
# ...

# %%
# def dateconverter(dataframe, column_index):
#     dates = dataframe.iloc[:,column_index].to_numpy()
#     date_series = pd.to_datetime([f"{month} {day}, {year}" for month, day in map(lambda x: x.split(), dates)])
#     dataframe[f'{column}'] = date_series

def dateconverter2(dataframe, column_index, column_name):
    dates = dataframe.iloc[:,column_index].to_numpy()
    date_series = np.array(pd.to_datetime([f"{month} {day}, {year}" for month, day in map(lambda x: x.split(), dates)]))
    dataframe[column_name] = date_series
    
# def dateconverter(dataframe, column):
#     dates = dataframe[column].to_numpy()
#     date_series = np.array(pd.to_datetime([f"{month} {day}, {year}" for month, day in map(lambda x: x.split(), dates)]))
#     dataframe[column] = date_series

# %%
dateconverter2(test, 0, "Release Date")

# %%
test
# Out:
#    Release Date                                              Title
# 0    2015-01-09                             Psycho-Pass: The Movie  \
# 1    2015-01-31               Arpeggio of Blue Steel -Ars Nova DC-
# 2    2015-02-20                           The Case of Hana & Alice
# 3    2015-03-06                                 Knights of Sidonia
# 4    2015-03-07                    Doraemon: Nobita's Space Heroes
# 5    2015-03-07  PriPara the Movie: Eeeeveryone, Assemble! Pris...
# 6    2015-03-13                              Shimajirō to Ōkina Ki
# 7    2015-03-14           Beyond the Boundary: I'll Be Here – Past
# 8    2015-04-05   Tamayura: Sotsugyō Shashin Dai-1-bu Me -Kizashi-
# 9    2015-04-12                        Le Labyrinthe de la Grisaia
# 10   2015-04-18             Detective Conan: Sunflowers of Inferno
# 11   2015-04-18  Crayon Shin-Chan: My Moving Story! Cactus Larg...
# 12   2015-04-18                    Dragon Ball Z: Resurrection 'F'
# ...

# %%
test['Release Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 37 entries, 0 to 36
# Series name: Release Date
# Non-Null Count  Dtype
# --------------  -----
# 37 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 424.0 bytes

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First Run Start and End Dates  163 non-null    object
#  1   Title                          163 non-null    object
#  2   Eps                            154 non-null    float64
#  3   Studio                         163 non-null    object
#  4   Director                       161 non-null    object
#  5   Alternate Title                69 non-null     object
#  6   Ref                            140 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 9.0+ KB

# %%
df1.loc[(df1['Eps'].isna()==True) | (df1['Director'].isna()==True)]
# df1.loc[(df1['Eps'].isna()) | (df1['Director'].isna())] #works the same way
# Out:
#     First Run Start and End Dates                                     Title
# 29                      April 1 –               Battle Spirits Burning Soul  \
# 53                      April 6 –             Ace of Diamond: Second Season
# 57                      April 8 –                                  Gintama°
# 109        July 13 – September 28                          Makura no Danshi
# 112                   October 1 –    Kami-sama Minarai: Himitsu no Cocotama
# 113                   October 1 –                       Kyo-fu! Zombie Neko
# 121                   October 3 –  Fafner in the Azure: Exodus (2nd season)
# 135                   October 4 –                           Owarimonogatari
# 137                   October 5 –                  High School Star Musical
# 143                   October 6 –                 DD Fist of the North Star
# 146                   October 6 –                                 JK Meshi!
#
#       Eps                    Studio            Director
# ...

# %%
nan_mask = df1.isnull().any(axis=1)

# Use the boolean mask with iloc to locate rows with NaN values
nan_rows = df1[nan_mask]

# %%
nan_rows
# Out:
#     First Run Start and End Dates                                Title   Eps
# 0            January 4 – March 22                         Absolute Duo  12.0  \
# 1            January 4 – March 29     Minna Atsumare! Falcom Gakuen SC  13.0
# 2            January 4 – March 28        Tantei Kageki Milky Holmes TD  12.0
# 3            January 5 – March 30                       Kamisama Kiss◎  12.0
# 4            January 5 – March 31                      Yurikuma Arashi  12.0
# ..                            ...                                  ...   ...
# 153  October 7 – January 27, 2016            Tantei Team KZ Jiken Note  16.0
# 159      October 10 – December 26              Valkyrie Drive: Mermaid  12.0
# 160   October 11 – March 27, 2016                          Brave Beats  22.0
# 161   October 11 – April 10, 2016  Cardfight!! Vanguard G: GIRS Crisis  26.0
# 162      October 12 – December 28                         Ani Tore! EX  12.0
#
# ...

# %%
df1.dropna(thresh=145, axis = 1, inplace= True) # we are attempting to drop Alternate Title and Ref cols and thus
# we will select a threshold such that all columns except those mentioned above will be able to satisfy
# that condition.

# %%
df1
# Out:
#     First Run Start and End Dates                                Title   Eps
# 0            January 4 – March 22                         Absolute Duo  12.0  \
# 1            January 4 – March 29     Minna Atsumare! Falcom Gakuen SC  13.0
# 2            January 4 – March 28        Tantei Kageki Milky Holmes TD  12.0
# 3            January 5 – March 30                       Kamisama Kiss◎  12.0
# 4            January 5 – March 31                      Yurikuma Arashi  12.0
# ..                            ...                                  ...   ...
# 158      October 10 – December 26  Seraph of the End: Battle in Nagoya  12.0
# 159      October 10 – December 26              Valkyrie Drive: Mermaid  12.0
# 160   October 11 – March 27, 2016                          Brave Beats  22.0
# 161   October 11 – April 10, 2016  Cardfight!! Vanguard G: GIRS Crisis  26.0
# 162      October 12 – December 28                         Ani Tore! EX  12.0
#
# ...

# %%
df1.loc[(df1['Eps'].isna()==True) | (df1['Director'].isna()==True)]
# Out:
#     First Run Start and End Dates                                     Title
# 29                      April 1 –               Battle Spirits Burning Soul  \
# 53                      April 6 –             Ace of Diamond: Second Season
# 57                      April 8 –                                  Gintama°
# 109        July 13 – September 28                          Makura no Danshi
# 112                   October 1 –    Kami-sama Minarai: Himitsu no Cocotama
# 113                   October 1 –                       Kyo-fu! Zombie Neko
# 121                   October 3 –  Fafner in the Azure: Exodus (2nd season)
# 135                   October 4 –                           Owarimonogatari
# 137                   October 5 –                  High School Star Musical
# 143                   October 6 –                 DD Fist of the North Star
# 146                   October 6 –                                 JK Meshi!
#
#       Eps                    Studio            Director
# ...

# %%
# df1.iloc[57,2]=367
df1.iloc[143,2]=12

# %%
df1.iloc[143,2]
# Out:
# 12.0

# %%
df1.loc[df1['Eps'].isna()==True]
# Out:
#     First Run Start and End Dates                                   Title
# 29                      April 1 –             Battle Spirits Burning Soul  \
# 53                      April 6 –           Ace of Diamond: Second Season
# 112                   October 1 –  Kami-sama Minarai: Himitsu no Cocotama
# 113                   October 1 –                     Kyo-fu! Zombie Neko
# 135                   October 4 –                         Owarimonogatari
# 137                   October 5 –                High School Star Musical
# 146                   October 6 –                               JK Meshi!
#
#      Eps                   Studio            Director
# 29   NaN              BN Pictures       Hajime Yatate
# 53   NaN  Madhouse Production I.G  Mitsuyuki Masuhara
# 112  NaN                      OLM         Norio Nitta
# 113  NaN         Kachidoki Studio      Hiroshi Namiki
# 135  NaN                    Shaft       Akiyuki Simbo
# ...

# %%
df1.loc[(df1['Eps'].isna()==True) | (df1['Director'].isna()==True)]
# Out:
#     First Run Start and End Dates                                     Title
# 29                      April 1 –               Battle Spirits Burning Soul  \
# 53                      April 6 –             Ace of Diamond: Second Season
# 109        July 13 – September 28                          Makura no Danshi
# 112                   October 1 –    Kami-sama Minarai: Himitsu no Cocotama
# 113                   October 1 –                       Kyo-fu! Zombie Neko
# 121                   October 3 –  Fafner in the Azure: Exodus (2nd season)
# 135                   October 4 –                           Owarimonogatari
# 137                   October 5 –                  High School Star Musical
# 146                   October 6 –                                 JK Meshi!
#
#       Eps                    Studio            Director
# 29    NaN               BN Pictures       Hajime Yatate
# 53    NaN   Madhouse Production I.G  Mitsuyuki Masuhara
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First Run Start and End Dates  163 non-null    object
#  1   Title                          163 non-null    object
#  2   Eps                            156 non-null    float64
#  3   Studio                         163 non-null    object
#  4   Director                       161 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 6.5+ KB

# %%
df1.dropna(inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154 entries, 0 to 162
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First Run Start and End Dates  154 non-null    object
#  1   Title                          154 non-null    object
#  2   Eps                            154 non-null    float64
#  3   Studio                         154 non-null    object
#  4   Director                       154 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 7.2+ KB

# %%
df1_cleaned = df1.reset_index(drop=True)

# %%
df1_cleaned
# Out:
#     First Run Start and End Dates                                Title   Eps
# 0            January 4 – March 22                         Absolute Duo  12.0  \
# 1            January 4 – March 29     Minna Atsumare! Falcom Gakuen SC  13.0
# 2            January 4 – March 28        Tantei Kageki Milky Holmes TD  12.0
# 3            January 5 – March 30                       Kamisama Kiss◎  12.0
# 4            January 5 – March 31                      Yurikuma Arashi  12.0
# ..                            ...                                  ...   ...
# 149      October 10 – December 26  Seraph of the End: Battle in Nagoya  12.0
# 150      October 10 – December 26              Valkyrie Drive: Mermaid  12.0
# 151   October 11 – March 27, 2016                          Brave Beats  22.0
# 152   October 11 – April 10, 2016  Cardfight!! Vanguard G: GIRS Crisis  26.0
# 153      October 12 – December 28                         Ani Tore! EX  12.0
#
# ...

# %%
df2
# Out:
#   Release Start Date                           Title   Studio        Director
# 0        February 13  Comical Psychosomatic Medicine  For All  Hirofumi Ogura  \
# 1           April 16     Ninja Slayer From Animation  Trigger   Akira Amemiya
#
#    Notes    Ref
# 0    NaN  [170]
# 1    NaN  [171]

# %%
df3
# Out:
#    Release Date                                              Title  Eps
# 0    January 30               Twin Angel: Kyun Tokimeki Paradise!!    2  \
# 1   February 23                                 Hōzuki no Reitetsu    3
# 2   February 25                      Exodus! Episode 1: Exit Tokyo    1
# 3   February 28  Mobile Suit Gundam: The Origin I - Blue-Eyed C...    1
# 4       March 6                        Shōwa Genroku Rakugo Shinjū    1
# 5      March 26  Senran Kagura: Estival Versus – Festival Eve F...    1
# 6      March 10                       Chaika - The Coffin Princess    1
# 7        May 30                             Haiyore! Nyaruko-san F    1
# 8       June 21             The Third Girls Aerial Squad Episode 1    1
# 9    January 22                  The Testament of Sister New Devil    1
# 10      April 9                        Attack on Titan: No Regrets    1
# 11     August 7                        Shōwa Genroku Rakugo Shinjū    1
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Release Date  19 non-null     object
#  1   Title         19 non-null     object
#  2   Eps           19 non-null     int64
#  3   Studio        19 non-null     object
#  4   Director      19 non-null     object
#  5   Notes         14 non-null     object
#  6   Ref           17 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.2+ KB

# %%
df3.loc[df3['Notes'].isna()]
# Out:
#    Release Date                                              Title  Eps
# 0    January 30               Twin Angel: Kyun Tokimeki Paradise!!    2  \
# 9    January 22                  The Testament of Sister New Devil    1
# 15   October 31  Mobile Suit Gundam: The Origin II - Artesia's ...    1
# 16  November 25                                   Strike the Blood    2
# 18  December 25                                  Tokyo Ghoul: Jack    1
#
#                  Studio                              Director Notes    Ref
# 0            J.C. Staff                      Yoshiaki Iwasaki   NaN    NaN
# 9        Production IMS                         Hisashi Saito   NaN  [178]
# 15              Sunrise  Yoshikazu Yasuhiko, Takashi Imanishi   NaN  [182]
# 16  Silver Link Connect           Takao Sano, Hideyo Yamamoto   NaN    NaN
# 18              Pierrot                 Tadahito Matsubayashi   NaN  [184]

# %%
df3['Notes'].fillna('None', inplace=True)

# %%
df3
# Out:
#    Release Date                                              Title  Eps
# 0    January 30               Twin Angel: Kyun Tokimeki Paradise!!    2  \
# 1   February 23                                 Hōzuki no Reitetsu    3
# 2   February 25                      Exodus! Episode 1: Exit Tokyo    1
# 3   February 28  Mobile Suit Gundam: The Origin I - Blue-Eyed C...    1
# 4       March 6                        Shōwa Genroku Rakugo Shinjū    1
# 5      March 26  Senran Kagura: Estival Versus – Festival Eve F...    1
# 6      March 10                       Chaika - The Coffin Princess    1
# 7        May 30                             Haiyore! Nyaruko-san F    1
# 8       June 21             The Third Girls Aerial Squad Episode 1    1
# 9    January 22                  The Testament of Sister New Devil    1
# 10      April 9                        Attack on Titan: No Regrets    1
# 11     August 7                        Shōwa Genroku Rakugo Shinjū    1
# ...

# %%
df3.dropna(axis=1, inplace = True)

# %%
df3
# Out:
#    Release Date                                              Title  Eps
# 0    January 30               Twin Angel: Kyun Tokimeki Paradise!!    2  \
# 1   February 23                                 Hōzuki no Reitetsu    3
# 2   February 25                      Exodus! Episode 1: Exit Tokyo    1
# 3   February 28  Mobile Suit Gundam: The Origin I - Blue-Eyed C...    1
# 4       March 6                        Shōwa Genroku Rakugo Shinjū    1
# 5      March 26  Senran Kagura: Estival Versus – Festival Eve F...    1
# 6      March 10                       Chaika - The Coffin Princess    1
# 7        May 30                             Haiyore! Nyaruko-san F    1
# 8       June 21             The Third Girls Aerial Squad Episode 1    1
# 9    January 22                  The Testament of Sister New Devil    1
# 10      April 9                        Attack on Titan: No Regrets    1
# 11     August 7                        Shōwa Genroku Rakugo Shinjū    1
# ...

# %%
df4
# Out:
#    Rank                                              Title          Gross
# 0     1                    Dragon Ball Z: Resurrection 'F'    $61,768,190  \
# 1     2                              The Boy and the Beast    $46,400,000
# 2     3             Detective Conan: Sunflowers of Inferno    $43,782,211
# 3     4                    Doraemon: Nobita's Space Heroes    $36,019,702
# 4     5                   Love Live! The School Idol Movie    $21,700,000
# 5     6  Yo-Kai Watch: Enma Daiō to Itsutsu no Monogata...  $19.4 million
# 6     7  Crayon Shin-Chan: My Moving Story! Cactus Larg...    $18,200,000
# 7     8                           Boruto: Naruto the Movie    $16,800,000
# 8     9     Pokémon the Movie: Hoopa and the Clash of Ages    $22,000,000
# 9    10                            The Anthem of the Heart     $8,505,999
#
#     Ref.
# 0  [185]
# 1  [186]
# 2  [187]
# 3  [188]
# 4  [189]
# 5  [190]
# 6  [191]
# 7  [192]
# 8  [193]
# 9  [194]

# %%
df4['Gross']=df4['Gross'].str.replace('$', '')

# %%
df4
# Out:
#    Rank                                              Title         Gross
# 0     1                    Dragon Ball Z: Resurrection 'F'    61,768,190  \
# 1     2                              The Boy and the Beast    46,400,000
# 2     3             Detective Conan: Sunflowers of Inferno    43,782,211
# 3     4                    Doraemon: Nobita's Space Heroes    36,019,702
# 4     5                   Love Live! The School Idol Movie    21,700,000
# 5     6  Yo-Kai Watch: Enma Daiō to Itsutsu no Monogata...  19.4 million
# 6     7  Crayon Shin-Chan: My Moving Story! Cactus Larg...    18,200,000
# 7     8                           Boruto: Naruto the Movie    16,800,000
# 8     9     Pokémon the Movie: Hoopa and the Clash of Ages    22,000,000
# 9    10                            The Anthem of the Heart     8,505,999
#
#     Ref.
# 0  [185]
# 1  [186]
# 2  [187]
# 3  [188]
# 4  [189]
# 5  [190]
# 6  [191]
# 7  [192]
# 8  [193]
# 9  [194]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    10 non-null     int64
#  1   Title   10 non-null     object
#  2   Gross   10 non-null     object
#  3   Ref.    10 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 448.0+ bytes

# %%
df5=tables[6]

# %%
df5
# Out:
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteYears in anime
# ...

# %% [markdown]
# ### New data

# %%
url = 'https://en.wikipedia.org/wiki/2020_in_anime'

# response = requests.get(url)

# # Check if the request was successful (status code 200)
# if response.status_code == 200:
#     html_content = response.text
# else:
#     print('Failed to retrieve the web page.')

# %%
tables = pd.read_html(html_content)

# %%
len(tables)
# Out:
# 6

# %%
df = tables[1]

# %%
df
# Out:
#               Release date                                              Title
# 0               January 10                        The Island of Giant Insects  \
# 1               January 17               Made in Abyss: Dawn of the Deep Soul
# 2               January 18                       High School Fleet: The Movie
# 3               February 1                      Goblin Slayer: Goblin's Crown
# 4              February 15    Saezuru Tori wa Habatakanai – The Clouds Gather
# 5              February 21           Digimon Adventure: Last Evolution Kizuna
# 6              February 21                   Sekai-ichi Hatsukoi: Propose-hen
# 7              February 29                               Shirobako: The Movie
# 8                 March 27                     Psycho-Pass 3: First Inspector
# 9                 August 7                    Doraemon: Nobita's New Dinosaur
# 10                August 7                  Revue Starlight Rondo Rondo Rondo
# ...

# %%
# learn the limitations of todatetime
date = pd.to_datetime('November 19 2023')

# %%
date
# Out:
# Timestamp('2023-11-19 00:00:00')

# %%
year = 2020

# %%
df['Release Date'] = pd.to_datetime(df['Release Date'].str+str(year))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Release Date'
#
# ...

# %%
x = df['Release date'].to_numpy() + str(' ') + str(year)

# %%
# date_series = pd.to_datetime([f"{month} {day}, {year}" for month, day in map(lambda x: x.split(), dates)])

# %%
pd.to_datetime(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[384], line 1
# ----> 1 pd.to_datetime(x)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1082, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1080         result = _convert_and_box_cache(argc, cache_array)
#    1081     else:
# -> 1082         result = convert_listlike(argc, format)
#    1083 else:
#    1084     result = convert_listlike(np.array([arg]), format)[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
# ...

# %%
x
# Out:
# array(['January 10 2020', 'January 17 2020', 'January 18 2020',
#        'February 1 2020', 'February 15 2020', 'February 21 2020',
#        'February 21 2020', 'February 29 2020', 'March 27 2020',
#        'August 7 2020', 'August 7 2020', 'August 14 2020',
#        'August 15 2020', 'August 22 2020', 'September 5 2020',
#        'September 11 2020', 'September 11 2020', 'September 11 2020',
#        'September 18 2020', 'September 18 2020', 'October 2 2020',
#        'October 2 2020', 'October 2 – October 30 2020', 'October 16 2020',
#        'October 23 2020', 'November 6 2020', 'November 13 2020',
#        'November 13 2020', 'November 20 2020', 'November 27 2020',
#        'November 27 2020', 'December 5 2020', 'December 11 2020',
#        'December 25 2020', 'December 25 2020', 'December 25 2020',
#        'December 30 2020'], dtype=object)

# %%
x[22]
# Out:
# 'October 2 – October 30 2020'

# %%
x[22] = 'October 2 2020'

# %%
pd.to_datetime(x)
# Out:
# DatetimeIndex(['2020-01-10', '2020-01-17', '2020-01-18', '2020-02-01',
#                '2020-02-15', '2020-02-21', '2020-02-21', '2020-02-29',
#                '2020-03-27', '2020-08-07', '2020-08-07', '2020-08-14',
#                '2020-08-15', '2020-08-22', '2020-09-05', '2020-09-11',
#                '2020-09-11', '2020-09-11', '2020-09-18', '2020-09-18',
#                '2020-10-02', '2020-10-02', '2020-10-02', '2020-10-16',
#                '2020-10-23', '2020-11-06', '2020-11-13', '2020-11-13',
#                '2020-11-20', '2020-11-27', '2020-11-27', '2020-12-05',
#                '2020-12-11', '2020-12-25', '2020-12-25', '2020-12-25',
#                '2020-12-30'],
#               dtype='datetime64[ns]', freq=None)

# %%
# Now the real stuff
df['Release date'] = pd.to_datetime(df['Release date'].to_numpy() + str(' ') + str(year))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[389], line 2
#       1 # Now the real stuff
# ----> 2 df['Release date'] = pd.to_datetime(df['Release date'].to_numpy() + str(' ') + str(year))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1082, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1080         result = _convert_and_box_cache(argc, cache_array)
#    1081     else:
# -> 1082         result = convert_listlike(argc, format)
#    1083 else:
#    1084     result = convert_listlike(np.array([arg]), format)[0]
#
# ...

# %%
df.iloc[22,0] = 'October 2'

# %%
# second try after a failed attempt
df['Release date'] = pd.to_datetime(df['Release date'].to_numpy() + str(' ') + str(year))

# %%
df
# Out:
#    Release date                                              Title
# 0    2020-01-10                        The Island of Giant Insects  \
# 1    2020-01-17               Made in Abyss: Dawn of the Deep Soul
# 2    2020-01-18                       High School Fleet: The Movie
# 3    2020-02-01                      Goblin Slayer: Goblin's Crown
# 4    2020-02-15    Saezuru Tori wa Habatakanai – The Clouds Gather
# 5    2020-02-21           Digimon Adventure: Last Evolution Kizuna
# 6    2020-02-21                   Sekai-ichi Hatsukoi: Propose-hen
# 7    2020-02-29                               Shirobako: The Movie
# 8    2020-03-27                     Psycho-Pass 3: First Inspector
# 9    2020-08-07                    Doraemon: Nobita's New Dinosaur
# 10   2020-08-07                  Revue Starlight Rondo Rondo Rondo
# 11   2020-08-14                      Date A Bullet: Dead or Bullet
# 12   2020-08-15    Fate/stay night: Heaven's Feel III. spring song
# ...

# %%
df['Release date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 37 entries, 0 to 36
# Series name: Release date
# Non-Null Count  Dtype
# --------------  -----
# 37 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 424.0 bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Release date            37 non-null     datetime64[ns]
#  1   Title                   37 non-null     object
#  2   Studio                  37 non-null     object
#  3   Director(s)             37 non-null     object
#  4   Running time (minutes)  36 non-null     float64
#  5   Ref                     37 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 1.9+ KB

# %%
df.loc[df['Running time (minutes)'].isna()]
# Out:
#    Release date                       Title            Studio     Director(s)
# 22   2020-10-02  Wave!!: Let's Go Surfing!!  Asahi Production  Takaharu Ozaki  \
#
#     Running time (minutes)   Ref
# 22                     NaN  [23]

# %%
df.iloc[21,4]
# Out:
# 63.0

# %%
df.iloc[23,4]
# Out:
# 117.0

# %%
# df.fillna(df.mean())
df['Running time (minutes)'].mean()
# Out:
# 90.11111111111111

# %%
df.fillna(df['Running time (minutes)'].mean(), inplace = True)

# %%
df.isna().sum()
# Out:
# Release date              0
# Title                     0
# Studio                    0
# Director(s)               0
# Running time (minutes)    0
# Ref                       0
# dtype: int64

# %%
df1 = tables[2]
df2 = tables[3]
df3 = tables[4]

# %%
len(tables)
# Out:
# 6

# %%
df1
# Out:
#      First run start and end dates
# 0             January 3 – March 27  \
# 1             January 3 – March 20
# 2             January 4 – March 28
# 3             January 5 – March 22
# 4             January 5 – March 22
# ..                             ...
# 138       October 13 – December 29
# 139    October 13 – March 30, 2021
# 140       October 14 – December 30
# 141  October 30 – January 29, 2021
# 142    December 7 – March 29, 2021
#
#                                                  Title  Episodes
# 0                                     Asteroid in Love      12.0  \
# 1                                        Darwin's Game      11.0
# 2    Magia Record: Puella Magi Madoka Magica Side S...      13.0
# 3                                          Id: Invaded      13.0
# 4                        Keep Your Hands Off Eizouken!      12.0
# ..                                                 ...       ...
# 138                          Magatsu Wahrheit -Zuerst-      12.0
# ...

# %%
# df1.loc[df['Title'] == 'Attack']
value1 = 'Jujutsu Kaisen'
value2 = 'Attack'
selected_rows = df1.loc[df1['Title'] == value1]

# %%
selected_rows
# Out:
#     First run start and end dates           Title  Episodes Studio
# 110    October 3 – March 27, 2021  Jujutsu Kaisen      24.0  MAPPA  \
#
#       Director(s) Original title    Ref
# 110  Sunghoo Park            NaN  [145]

# %%
df1.iloc[110,1]
# Out:
# 'Jujutsu Kaisen'

# %%
# date_series = pd.to_datetime([f"{month} {day}, {year}" for month, day in map(lambda x: x.split(), date_strings)])

# %%
df1.loc[df1['Title'] == 'Attack']
# Out:
# Empty DataFrame
# Columns: [First run start and end dates, Title, Episodes, Studio, Director(s), Original title, Ref]
# Index: []

# %%
year = 2015
date_strings = ['October 29', 'November 15', 'December 5']

# Convert to datetime with the specified year
date_series = pd.to_datetime([f"{month} {day}, {year}" for month, day in map(lambda x: x.split(), date_strings)])
# df['DateColumn'] = df['DateColumn'].str.split(' ').apply(lambda x: f"{x[1]}-{month_mapping[x[0]]}-{pd.Timestamp.now().year}")
print(date_series)
# Out:
# DatetimeIndex(['2015-10-29', '2015-11-15', '2015-12-05'], dtype='datetime64[ns]', freq=None)

# %%
date_strings = ['October 29', 'November 15', 'December 5']
# date_strings.split()
x = df1['Title'].apply(lambda x: x.split()).to_numpy()

# %%
################# very very important

df1[df1['Title'].str.contains('Jujutsu', case=False)] 

################# very very important
# Out:
#     First run start and end dates           Title  Episodes Studio
# 110    October 3 – March 27, 2021  Jujutsu Kaisen      24.0  MAPPA  \
#
#       Director(s) Original title    Ref
# 110  Sunghoo Park            NaN  [145]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First run start and end dates  143 non-null    object
#  1   Title                          143 non-null    object
#  2   Episodes                       142 non-null    float64
#  3   Studio                         143 non-null    object
#  4   Director(s)                    143 non-null    object
#  5   Original title                 78 non-null     object
#  6   Ref                            141 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 7.9+ KB

# %%
df1.drop('Ref', axis=1, inplace =True)

# %%
df1
# Out:
#      First run start and end dates
# 0             January 3 – March 27  \
# 1             January 3 – March 20
# 2             January 4 – March 28
# 3             January 5 – March 22
# 4             January 5 – March 22
# ..                             ...
# 138       October 13 – December 29
# 139    October 13 – March 30, 2021
# 140       October 14 – December 30
# 141  October 30 – January 29, 2021
# 142    December 7 – March 29, 2021
#
#                                                  Title  Episodes
# 0                                     Asteroid in Love      12.0  \
# 1                                        Darwin's Game      11.0
# 2    Magia Record: Puella Magi Madoka Magica Side S...      13.0
# 3                                          Id: Invaded      13.0
# 4                        Keep Your Hands Off Eizouken!      12.0
# ..                                                 ...       ...
# 138                          Magatsu Wahrheit -Zuerst-      12.0
# ...

# %%
df1[df1['Episodes'].isna()]
# Out:
#    First run start and end dates                             Title  Episodes
# 42                     April 2 –  Auto Boy - Carl from Mobile Land       NaN  \
#
#          Studio     Director(s)
# 42  CloverWorks  Shinobu Sasaki

# %%
df1.iloc[43,2]
# Out:
# 12.0

# %%
df1['Episodes'].mean().astype('int64')
# Out:
# 15

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First run start and end dates  143 non-null    object
#  1   Title                          143 non-null    object
#  2   Episodes                       142 non-null    float64
#  3   Studio                         143 non-null    object
#  4   Director(s)                    143 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 5.7+ KB

# %%
df1['Episodes']=df1['Episodes'].fillna(df1['Episodes'].mean().astype('int64'))

# %%
df1.iloc[42,2]
# Out:
# 15.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First run start and end dates  143 non-null    object
#  1   Title                          143 non-null    object
#  2   Episodes                       143 non-null    float64
#  3   Studio                         143 non-null    object
#  4   Director(s)                    143 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 5.7+ KB

# %%
df2
# Out:
#    First run start and end dates
# 0          January 15 – August 6  \
# 1                     February 6
# 2                       March 19
# 3                       March 20
# 4                       March 23
# 5                       March 26
# 6       April 3 – March 19, 2021
# 7            April 9 – August 27
# 8         April 10 – November 20
# 9             April 10 – June 26
# 10                      April 23
# 11                        June 4
# 12                       June 18
# 13                        July 9
# 14                     August 16
# 15                     August 27
# 16                  September 17
# 17                    October 11
# 18                  October 11 –
# 19                    December 1
#
#                                                 Title  Episodes
# 0                             Pokémon: Twilight Wings       7.0  \
# 1                          Cagaster of an Insect Cage      12.0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First run start and end dates  20 non-null     object
#  1   Title                          20 non-null     object
#  2   Episodes                       19 non-null     float64
#  3   Studio                         20 non-null     object
#  4   Director(s)                    19 non-null     object
#  5   Original title                 7 non-null      object
#  6   Ref                            19 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 1.2+ KB

# %%
df2.loc[df2['Episodes'].isna()]
# Out:
#    First run start and end dates                Title  Episodes   Studio
# 18                  October 11 –  Onegai Patron-sama!       NaN  TANOsim  \
#
#    Director(s) Original title    Ref
# 18         NaN            NaN  [195]

# %%
df2.drop(18, inplace = True)

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2.drop(['Ref'], axis = 1, inplace=True)

# %%
df2.drop(['Original title'], axis = 1, inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First run start and end dates  19 non-null     object
#  1   Title                          19 non-null     object
#  2   Episodes                       19 non-null     float64
#  3   Studio                         19 non-null     object
#  4   Director(s)                    19 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 888.0+ bytes

# %%
df3
# Out:
#    First run start and end dates
# 0                     January 22  \
# 1                     January 22
# 2                     January 29
# 3                     January 29
# 4                    February 14
# 5                    February 27
# 6                    February 28
# 7                    February 27
# 8                       March 25
# 9                        April 3
# 10       April 8 – June 30, 2021
# 11                     August 26
# 12                   September 2
# 13      October 25 – November 29
#
#                                                 Title  Episodes
# 0                               Haikyu!! Land vs. Sky         2  \
# 1                                           Tsugumomo         1
# 2   Is It Wrong to Try to Pick Up Girls in a Dungeon?         1
# 3                   Strike the Blood: Kieta Seisō-hen         1
# 4       ACCA: 13-Territory Inspection Dept. - Regards         1
# 5                                     The Ones Within         1
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First run start and end dates  14 non-null     object
#  1   Title                          14 non-null     object
#  2   Episodes                       14 non-null     int64
#  3   Studio                         14 non-null     object
#  4   Director(s)                    14 non-null     object
#  5   Original title                 10 non-null     object
#  6   Ref                            14 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 912.0+ bytes

# %%
df3.loc[df3['Original title'].isna()]
# Out:
#    First run start and end dates                               Title
# 1                     January 22                           Tsugumomo  \
# 3                     January 29   Strike the Blood: Kieta Seisō-hen
# 6                    February 28  Queen's Blade: Unlimited (2nd OVA)
# 10       April 8 – June 30, 2021                 Strike the Blood IV
#
#     Episodes   Studio      Director(s) Original title    Ref
# 1          1   Zero-G   Ryōichi Kuraya            NaN  [198]
# 3          1  Connect  Hideyo Yamamoto            NaN  [200]
# 6          1   FORTES    Gabi Kisaragi            NaN  [203]
# 10        12  Connect  Hideyo Yamamoto            NaN  [200]

# %%
df3.fillna('None', inplace=True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First run start and end dates  14 non-null     object
#  1   Title                          14 non-null     object
#  2   Episodes                       14 non-null     int64
#  3   Studio                         14 non-null     object
#  4   Director(s)                    14 non-null     object
#  5   Original title                 14 non-null     object
#  6   Ref                            14 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 912.0+ bytes

# %%
df4
# Out:
#    Rank                                              Title         Gross
# 0     1                    Dragon Ball Z: Resurrection 'F'    61,768,190  \
# 1     2                              The Boy and the Beast    46,400,000
# 2     3             Detective Conan: Sunflowers of Inferno    43,782,211
# 3     4                    Doraemon: Nobita's Space Heroes    36,019,702
# 4     5                   Love Live! The School Idol Movie    21,700,000
# 5     6  Yo-Kai Watch: Enma Daiō to Itsutsu no Monogata...  19.4 million
# 6     7  Crayon Shin-Chan: My Moving Story! Cactus Larg...    18,200,000
# 7     8                           Boruto: Naruto the Movie    16,800,000
# 8     9     Pokémon the Movie: Hoopa and the Clash of Ages    22,000,000
# 9    10                            The Anthem of the Heart     8,505,999
#
#     Ref.
# 0  [185]
# 1  [186]
# 2  [187]
# 3  [188]
# 4  [189]
# 5  [190]
# 6  [191]
# 7  [192]
# 8  [193]
# 9  [194]

# %%
df1[df1['Studio'].str.contains('mappa',case=False)]
# Out:
#     First run start and end dates                                       Title
# 24           January 9 – March 19           Uchitama?! Have you seen my Tama?  \
# 34          January 12 – March 29                                  Dorohedoro
# 46              April 3 – June 19                                   Listeners
# 83          July 6 – September 28                      The God of High School
# 98         July 15 – September 30                     Mr Love: Queen's Choice
# 110    October 3 – March 27, 2021                              Jujutsu Kaisen
# 135      October 11 – December 20                      The Gymnastics Samurai
# 142   December 7 – March 29, 2021  Attack on Titan: The Final Season (part 1)
#
#      Episodes             Studio                            Director(s)
# 24       11.0  MAPPA Lapin Track                        Kiyoshi Matsuda
# 34       12.0              MAPPA                       Yuichiro Hayashi
# ...

# %%
url = "https://en.wikipedia.org/wiki/2022_in_anime"

response = requests.get(url)

if response.status_code == 200:
    html_content = response.text

# %%
tables = pd.read_html(html_content)

# %%
response
# Out:
# <Response [200]>

# %%
# response.text 
# interesting stuff

# %%
df = tables[1]
df1 = tables[2]
df2 = tables[3]
df3 = tables[4]
df4 = tables[5]

# %%
len(tables)
# Out:
# 6

# %%
df
# Out:
#                   Release date
# 0                    January 1  \
# 1     January 28 – February 11
# 2                   January 30
# 3                   February 4
# 4                   February 4
# 5                  February 18
# 6                  February 18
# 7                  February 25
# 8                      March 4
# 9                      March 4
# 10                     March 4
# 11            March 4 – May 13
# 12                    March 11
# 13                     April 1
# 14                    April 15
# 15                    April 22
# 16                    April 22
# 17                    April 28
# 18                    April 29
# 19                      May 20
# 20        May 20 – September 1
# 21                      June 3
# 22                     June 10
# 23                     June 10
# 24                     June 11
# 25                     June 24
# 26                      July 1
# 27                      July 2
# 28                      July 8
# ...

# %%
df.iloc[1,0]
# Out:
# 'January 28 – February 11'

# %%
df.iloc[1,0]='January 28'

# %%
df.iloc[11,0]
# Out:
# 'March 4 – May 13'

# %%
df.iloc[11,0]='March 4'

# %%
df.iloc[20,0]
# Out:
# 'May 20 – September 1'

# %%
df.iloc[20,0]='May 20'

# %%
df.iloc[38,0]
# Out:
# 'September 30 – November 25'

# %%
df.iloc[38,0]='September 30'

# %%
df[df['Release date'].str.contains(' – ')]
# Out:
#                   Release date
# 1     January 28 – February 11  \
# 11            March 4 – May 13
# 20        May 20 – September 1
# 38  September 30 – November 25
#
#                                                 Title          Studio
# 1                                The Orbital Children   Production +h  \
# 11  Legend of the Galactic Heroes: The New Thesis ...  Production I.G
# 20         Toku Touken Ranbu: Hanamaru ~Setsugetsuka~       Doga Kobo
# 38  Legend of the Galactic Heroes: The New Thesis ...  Production I.G
#
#                                  Director(s)  Running time (minutes)   Ref
# 1                                 Mitsuo Iso                     NaN   [2]
# 11                             Shunsuke Tada                     NaN  [12]
# 20  Takashi Naoya Tomoaki Koshida Sumie Noro                     NaN  [21]
# 38                             Shunsuke Tada                     NaN  [39]

# %%
df[df['Release date'].str.contains(' – ')]
# Out:
# Empty DataFrame
# Columns: [Release date, Title, Studio, Director(s), Running time (minutes), Ref]
# Index: []

# %%
df
# Out:
#     Release date                                              Title
# 0      January 1                         BanG Dream! Poppin' Dream!  \
# 1     January 28                               The Orbital Children
# 2     January 30                                        Eien no 831
# 3     February 4  Star Blazers: Space Battleship Yamato 2205: Ko...
# 4     February 4                                      The Deer King
# 5    February 18                             Fruits Basket: Prelude
# 6    February 18                                Goodbye, Don Glees!
# 7    February 25                               Deemo: Memorial Keys
# 8        March 4                                       Blue Thermal
# 9        March 4           Doraemon: Nobita's Little Star Wars 2021
# 10       March 4                    Ensemble Stars!! Road to Show!!
# 11       March 4  Legend of the Galactic Heroes: The New Thesis ...
# 12      March 11            Shimajirō to Kirakira Ōkoku no Ōji-sama
# ...

# %%
year = 2022
df['Release date']= pd.to_datetime(df['Release date'].to_numpy() + str(' ') + str(year))

# %%
df.head()
# Out:
#   Release date                                              Title
# 0   2022-01-01                         BanG Dream! Poppin' Dream!  \
# 1   2022-01-28                               The Orbital Children
# 2   2022-01-30                                        Eien no 831
# 3   2022-02-04  Star Blazers: Space Battleship Yamato 2205: Ko...
# 4   2022-02-04                                      The Deer King
#
#            Studio                             Director(s)
# 0        Sanzigen  Kōdai Kakimoto (Chief) Masanori Uetaka  \
# 1   Production +h                              Mitsuo Iso
# 2         Craftar                          Kenji Kamiyama
# 3       Satelight                            Kenji Yasuda
# 4  Production I.G            Masashi Ando Masayuki Miyaji
#
#    Running time (minutes)  Ref
# 0                    72.0  [1]
# 1                     NaN  [2]
# 2                   105.0  [3]
# 3                    97.0  [4]
# 4                   114.0  [5]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Release date            53 non-null     datetime64[ns]
#  1   Title                   53 non-null     object
#  2   Studio                  53 non-null     object
#  3   Director(s)             53 non-null     object
#  4   Running time (minutes)  45 non-null     float64
#  5   Ref                     53 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 2.6+ KB

# %%
df.loc[df['Running time (minutes)'].isna()]
# Out:
#    Release date                                              Title
# 1    2022-01-28                               The Orbital Children  \
# 11   2022-03-04  Legend of the Galactic Heroes: The New Thesis ...
# 20   2022-05-20         Toku Touken Ranbu: Hanamaru ~Setsugetsuka~
# 31   2022-07-31                        Joshi Kōsei to Mahō no Note
# 38   2022-09-30  Legend of the Galactic Heroes: The New Thesis ...
# 48   2022-12-03                                The First Slam Dunk
# 49   2022-12-09               Kaiketsu Zorori: La La La Sutā Tanjō
# 51   2022-12-20  The Seven Deadly Sins: Grudge of Edinburgh (pa...
#
#                                            Studio
# 1                                   Production +h  \
# 11                                 Production I.G
# 20                                      Doga Kobo
# 31                                          Noovo
# 38                                 Production I.G
# 48      Toei Animation Dandelion Animation Studio
# ...

# %%
df
# Out:
#    Release date                                              Title
# 0    2022-01-01                         BanG Dream! Poppin' Dream!  \
# 1    2022-01-28                               The Orbital Children
# 2    2022-01-30                                        Eien no 831
# 3    2022-02-04  Star Blazers: Space Battleship Yamato 2205: Ko...
# 4    2022-02-04                                      The Deer King
# 5    2022-02-18                             Fruits Basket: Prelude
# 6    2022-02-18                                Goodbye, Don Glees!
# 7    2022-02-25                               Deemo: Memorial Keys
# 8    2022-03-04                                       Blue Thermal
# 9    2022-03-04           Doraemon: Nobita's Little Star Wars 2021
# 10   2022-03-04                    Ensemble Stars!! Road to Show!!
# 11   2022-03-04  Legend of the Galactic Heroes: The New Thesis ...
# 12   2022-03-11            Shimajirō to Kirakira Ōkoku no Ōji-sama
# ...

# %%
df['Running time (minutes)'].mean()
# Out:
# 96.4888888888889

# %%
df['Running time (minutes)'].fillna(df['Running time (minutes)'].mean().astype('int64'), inplace=True)

# %%
df.head(10)
# Out:
#   Release date                                              Title
# 0   2022-01-01                         BanG Dream! Poppin' Dream!  \
# 1   2022-01-28                               The Orbital Children
# 2   2022-01-30                                        Eien no 831
# 3   2022-02-04  Star Blazers: Space Battleship Yamato 2205: Ko...
# 4   2022-02-04                                      The Deer King
# 5   2022-02-18                             Fruits Basket: Prelude
# 6   2022-02-18                                Goodbye, Don Glees!
# 7   2022-02-25                               Deemo: Memorial Keys
# 8   2022-03-04                                       Blue Thermal
# 9   2022-03-04           Doraemon: Nobita's Little Star Wars 2021
#
#                         Studio                                  Director(s)
# 0                     Sanzigen       Kōdai Kakimoto (Chief) Masanori Uetaka  \
# 1                Production +h                                   Mitsuo Iso
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Release date            53 non-null     datetime64[ns]
#  1   Title                   53 non-null     object
#  2   Studio                  53 non-null     object
#  3   Director(s)             53 non-null     object
#  4   Running time (minutes)  53 non-null     float64
#  5   Ref                     53 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 2.6+ KB

# %%
df1
# Out:
#     First run start and end dates                                 Title
# 0            January 5 – March 23                In the Land of Leadale  \
# 1         January 5 – February 23                         Irodorimidori
# 2            January 5 – March 30                       Police in a Pod
# 3            January 6 – March 24                       Orient (part 1)
# 4            January 6 – March 31                Saiyuki Reload: Zeroin
# ..                            ...                                   ...
# 182      October 16 – December 25           The Little Lies We All Tell
# 183   October 23 – March 12, 2023           To Your Eternity (season 2)
# 184      October 29 – December 17            Arknights: Prelude to Dawn
# 185   November 4 – March 25, 2023  Kantai Collection: Let's Meet at Sea
# 186    December 5 – June 19, 2023                           Me & Roboco
#
#      Episodes           Studio         Director(s)
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First run start and end dates  187 non-null    object
#  1   Title                          187 non-null    object
#  2   Episodes                       178 non-null    float64
#  3   Studio                         187 non-null    object
#  4   Director(s)                    186 non-null    object
#  5   Original title                 109 non-null    object
#  6   Ref                            187 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 10.4+ KB

# %%
df1.loc[df1['Episodes'].isna()]
# Out:
#      First run start and end dates                             Title
# 35                    February 6 –       Delicious Party Pretty Cure  \
# 43                       April 2 –                 Shadowverse Flame
# 49                       April 4 –                          Chiikawa
# 51                       April 4 –                       Insect Land
# 86                        July 2 –                     Iii Icecrin 2
# 132                 September 27 –        Chickip Dancers (season 2)
# 144  October 2 – February 26, 2023    Idolish7: Third Beat! (part 2)
# 147                    October 2 –                         PuniRunes
# 149                    October 3 –  Mamekichi Mameko NEET no Nichijō
#
#      Episodes                 Studio          Director(s)
# 35        NaN         Toei Animation   Toshinori Fukazawa  \
# 43        NaN                  Zexcs  Keiichiro Kawaguchi
# 49        NaN              Doga Kobo      Takenori Mihara
# ...

# %%
df1.iloc[143,2]
# Out:
# 4.0

# %%
df1['Episodes'].mean()
# Out:
# 13.758426966292134

# %%
df1['Episodes'].fillna(method='bfill',inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First run start and end dates  187 non-null    object
#  1   Title                          187 non-null    object
#  2   Episodes                       187 non-null    float64
#  3   Studio                         187 non-null    object
#  4   Director(s)                    186 non-null    object
#  5   Original title                 109 non-null    object
#  6   Ref                            187 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 10.4+ KB

# %%
df1['Original title'].fillna('None',inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First run start and end dates  187 non-null    object
#  1   Title                          187 non-null    object
#  2   Episodes                       187 non-null    float64
#  3   Studio                         187 non-null    object
#  4   Director(s)                    186 non-null    object
#  5   Original title                 187 non-null    object
#  6   Ref                            187 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 10.4+ KB

# %%
df1.loc[df1['Director(s)'].isna()]
# Out:
#     First run start and end dates                                     Title
# 163       October 6 – December 22  Sylvanian Families: Flare no Happy Diary  \
#
#      Episodes         Studio Director(s) Original title    Ref
# 163      12.0  LandQ Studios         NaN           None  [216]

# %%
df1.drop(163, inplace=True)

# %%
df1.reset_index(drop=True)
# Out:
#     First run start and end dates                                 Title
# 0            January 5 – March 23                In the Land of Leadale  \
# 1         January 5 – February 23                         Irodorimidori
# 2            January 5 – March 30                       Police in a Pod
# 3            January 6 – March 24                       Orient (part 1)
# 4            January 6 – March 31                Saiyuki Reload: Zeroin
# ..                            ...                                   ...
# 181      October 16 – December 25           The Little Lies We All Tell
# 182   October 23 – March 12, 2023           To Your Eternity (season 2)
# 183      October 29 – December 17            Arknights: Prelude to Dawn
# 184   November 4 – March 25, 2023  Kantai Collection: Let's Meet at Sea
# 185    December 5 – June 19, 2023                           Me & Roboco
#
#      Episodes           Studio         Director(s)
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186 entries, 0 to 186
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First run start and end dates  186 non-null    object
#  1   Title                          186 non-null    object
#  2   Episodes                       186 non-null    float64
#  3   Studio                         186 non-null    object
#  4   Director(s)                    186 non-null    object
#  5   Original title                 186 non-null    object
#  6   Ref                            186 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 11.6+ KB

# %%
df3
# Out:
#    First run start and end dates
# 0                     January 28  \
# 1                     February 4
# 2                       March 10
# 3                       March 16
# 4                       March 23
# 5             March 30 – July 29
# 6                       April 27
# 7                        June 17
# 8            June 24 – August 24
# 9                        July 27
# 10                  September 25
# 11                    October 26
# 12                   November 22
# 13     November 25 – December 23
# 14                    December 8
#
#                                                 Title  Episodes
# 0          Otome wa Boku ni Koishiteru: Trinkle Stars         1  \
# 1                                      Hairpin Double         1
# 2          The Girl from the Other Side: Siúil, a Rún         1
# 3               Mushoku Tensei: Jobless Reincarnation         1
# 4                              Non Non Biyori Nonstop         1
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First run start and end dates  15 non-null     object
#  1   Title                          15 non-null     object
#  2   Episodes                       15 non-null     int64
#  3   Studio                         15 non-null     object
#  4   Director(s)                    15 non-null     object
#  5   Original title                 7 non-null      object
#  6   Ref                            15 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 968.0+ bytes

# %%
df3.drop('Original title', axis=1, inplace=True)

# %%
df3
# Out:
#    First run start and end dates
# 0                     January 28  \
# 1                     February 4
# 2                       March 10
# 3                       March 16
# 4                       March 23
# 5             March 30 – July 29
# 6                       April 27
# 7                        June 17
# 8            June 24 – August 24
# 9                        July 27
# 10                  September 25
# 11                    October 26
# 12                   November 22
# 13     November 25 – December 23
# 14                    December 8
#
#                                                 Title  Episodes
# 0          Otome wa Boku ni Koishiteru: Trinkle Stars         1  \
# 1                                      Hairpin Double         1
# 2          The Girl from the Other Side: Siúil, a Rún         1
# 3               Mushoku Tensei: Jobless Reincarnation         1
# 4                              Non Non Biyori Nonstop         1
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   First run start and end dates  15 non-null     object
#  1   Title                          15 non-null     object
#  2   Episodes                       15 non-null     int64
#  3   Studio                         15 non-null     object
#  4   Director(s)                    15 non-null     object
#  5   Ref                            15 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 848.0+ bytes

# %%
df4
# Out:
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteYears in anime
# ...

# %%
df5
# Out:
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteYears in anime
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[679], line 1
# ----> 1 df6
#
# NameError: name 'df6' is not defined

# %%
cols=['Color','Director','2','3','4','Title','6','Country','PG Rating','Gross','Release Year','Rating','Genre']

# %%
df= pd.read_csv('/Users/owais/Jupyter Notebook/movies.csv', sep='|', header=None, names=cols)

# %%
df
# Out:
#     Color           Director      2      3            4
# 0   Color      James Cameron  723.0  178.0  760505847.0  \
# 1   Color     Gore Verbinski  302.0  169.0  309404152.0
# 2   Color         Sam Mendes  602.0  148.0  200074175.0
# 3   Color  Christopher Nolan  813.0  164.0  448130642.0
# 4       ?        Doug Walker      ?      ?            ?
# ..    ...                ...    ...    ...          ...
# 95  Color         James Gunn  653.0  121.0  333130696.0
# 96  Color  Christopher Nolan  712.0  169.0  187991439.0
# 97  Color  Christopher Nolan  642.0  148.0  292568851.0
# 98  Color       Hideaki Anno    1.0  120.0            ?
# 99  Color      Peter Jackson  645.0  182.0  303001229.0
#
#                                                 Title       6 Country
# 0                                             Avatar   3054.0     USA  \
# 1           Pirates of the Caribbean: At World's End   1238.0     USA
# 2                                            Spectre    994.0      UK
# ...

# %%
df.isna().sum()
# Out:
# Color           0
# Director        0
# 2               0
# 3               0
# 4               0
# Title           0
# 6               0
# Country         0
# PG Rating       0
# Gross           0
# Release Year    0
# Rating          0
# Genre           0
# dtype: int64

# %%
# df[df[cols].str.contains('\?')]
df[df[cols].astype(str).apply(lambda col: col.str.contains('\?')).any(axis=1)]
# Out:
#     Color      Director      2      3            4
# 4       ?   Doug Walker      ?      ?            ?  \
# 55  Color    Peter Sohn  298.0   93.0  123070338.0
# 84  Color  Roland Joffé   10.0  109.0            ?
# 98  Color  Hideaki Anno    1.0  120.0            ?
#
#                                                 Title      6  Country
# 4   Star Wars: Episode VII - The Force Awakens    ...      ?        ?  \
# 55                                 The Good Dinosaur   345.0      USA
# 84                                        The Lovers    15.0  Belgium
# 98                               Godzilla Resurgence    13.0    Japan
#
#    PG Rating Gross Release Year  Rating        Genre
# 4          ?     ?            ?     7.1  Documentary
# 55        PG     ?       2015.0     6.8    Adventure
# 84         R     ?       2015.0     4.5       Action
# 98         ?     ?       2016.0     8.2       Action

# %%
df[cols]
# Out:
#     Color           Director      2      3            4
# 0   Color      James Cameron  723.0  178.0  760505847.0  \
# 1   Color     Gore Verbinski  302.0  169.0  309404152.0
# 2   Color         Sam Mendes  602.0  148.0  200074175.0
# 3   Color  Christopher Nolan  813.0  164.0  448130642.0
# 4       ?        Doug Walker      ?      ?            ?
# ..    ...                ...    ...    ...          ...
# 95  Color         James Gunn  653.0  121.0  333130696.0
# 96  Color  Christopher Nolan  712.0  169.0  187991439.0
# 97  Color  Christopher Nolan  642.0  148.0  292568851.0
# 98  Color       Hideaki Anno    1.0  120.0            ?
# 99  Color      Peter Jackson  645.0  182.0  303001229.0
#
#                                                 Title       6 Country
# 0                                             Avatar   3054.0     USA  \
# 1           Pirates of the Caribbean: At World's End   1238.0     USA
# 2                                            Spectre    994.0      UK
# ...

# %%
df.drop([4,55,84,98], axis=0, inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#     Color           Director      2      3            4
# 0   Color      James Cameron  723.0  178.0  760505847.0  \
# 1   Color     Gore Verbinski  302.0  169.0  309404152.0
# 2   Color         Sam Mendes  602.0  148.0  200074175.0
# 3   Color  Christopher Nolan  813.0  164.0  448130642.0
# 4   Color     Andrew Stanton  462.0  132.0   73058679.0
# ..    ...                ...    ...    ...          ...
# 91  Color    Jonathan Mostow  280.0  109.0  150350192.0
# 92  Color         James Gunn  653.0  121.0  333130696.0
# 93  Color  Christopher Nolan  712.0  169.0  187991439.0
# 94  Color  Christopher Nolan  642.0  148.0  292568851.0
# 95  Color      Peter Jackson  645.0  182.0  303001229.0
#
#                                         Title       6 Country PG Rating
# 0                                     Avatar   3054.0     USA     PG-13  \
# 1   Pirates of the Caribbean: At World's End   1238.0     USA     PG-13
# 2                                    Spectre    994.0      UK     PG-13
# ...

# %%
df.isnull().sum()
# Out:
# Color           0
# Director        0
# 2               0
# 3               0
# 4               0
# Title           0
# 6               0
# Country         0
# PG Rating       0
# Gross           0
# Release Year    0
# Rating          0
# Genre           0
# dtype: int64

# %%
df.to_csv('movies_cleaned.csv',index=False)
