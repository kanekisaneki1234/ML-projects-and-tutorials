# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/owais/Jupyter Notebook/vgsales.csv')

# %%
df
# Out:
#         Rank                                              Name Platform
# 0          1                                        Wii Sports      Wii  \
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales
# ...

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000  \
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.values
# Out:
# array([[1, 'Wii Sports', 'Wii', ..., 3.77, 8.46, 82.74],
#        [2, 'Super Mario Bros.', 'NES', ..., 6.81, 0.77, 40.24],
#        [3, 'Mario Kart Wii', 'Wii', ..., 3.79, 3.31, 35.82],
#        ...,
#        [16598, 'SCORE International Baja 1000: The Official Game', 'PS2',
#         ..., 0.0, 0.0, 0.01],
#        [16599, 'Know How 2', 'DS', ..., 0.0, 0.0, 0.01],
#        [16600, 'Spirits & Spells', 'GBA', ..., 0.0, 0.0, 0.01]],
#       dtype=object)

# %%
# shift + tab for more info and tab for suggestions

# %%
import pandas as pd
import random

# Create lists for age groups, genders, and music genres
# age_groups = ['18-24', '25-34', '35-44', '45-54', '55+']
genders = ['Male', 'Female']
music_genres = ['Pop', 'Rock', 'Hip-Hop', 'Jazz', 'Country', 'Electronic', 'Classical', 'R&B']

# Generate random data for the dataset
data = []
for _ in range(30):  # Generate data for 100 individuals
    age = random.randint(20,41)
    gender = random.choice(genders)
    genre = random.choice(music_genres)
    data.append([age, gender, genre])

# Create a DataFrame from the generated data
columns = ['Age Group', 'Gender', 'Music Genre']
df = pd.DataFrame(data, columns=columns)

# Display the first few rows of the dataset
print(df.head())
# Out:
#    Age Group  Gender Music Genre
# 0         20    Male         Pop
# 1         39  Female         R&B
# 2         22  Female     Hip-Hop
# 3         40  Female     Country
# 4         40    Male         Pop

# %%
df
# Out:
#     Age Group  Gender Music Genre
# 0          20    Male         Pop
# 1          39  Female         R&B
# 2          22  Female     Hip-Hop
# 3          40  Female     Country
# 4          40    Male         Pop
# 5          23    Male     Hip-Hop
# 6          41  Female         R&B
# 7          37  Female         R&B
# 8          28  Female   Classical
# 9          40  Female     Hip-Hop
# 10         35  Female        Rock
# 11         27  Female        Rock
# 12         38    Male     Country
# 13         34  Female        Rock
# 14         32    Male  Electronic
# 15         39    Male     Hip-Hop
# 16         23    Male   Classical
# 17         41  Female         Pop
# 18         33  Female        Rock
# 19         29  Female         Pop
# 20         20    Male   Classical
# 21         32    Male        Jazz
# 22         31    Male  Electronic
# 23         36    Male     Country
# 24         21    Male        Rock
# 25         39    Male        Rock
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age Group    30 non-null     int64
#  1   Gender       30 non-null     object
#  2   Music Genre  30 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 848.0+ bytes

# %%
df.describe()
# Out:
#        Age Group
# count  30.000000
# mean   31.666667
# std     7.174348
# min    20.000000
# 25%    24.750000
# 50%    32.500000
# 75%    38.750000
# max    41.000000

# %%
df['Gender'] = df['Gender'].str.replace('Male','0')

# %%
df['Gender'] = df['Gender'].str.replace('Female','1')

# %%
df.head()
# Out:
#    Age Group Gender Music Genre
# 0         20      0         Pop
# 1         39      1         R&B
# 2         22      1     Hip-Hop
# 3         40      1     Country
# 4         40      0         Pop

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age Group    30 non-null     int64
#  1   Gender       30 non-null     object
#  2   Music Genre  30 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 848.0+ bytes

# %%
df['Gender']=df['Gender'].astype('int64')

# %%
x=21

# %%
while x<=20:
    df.iloc[x,2]='Trap'
    x+=1

# %%
df.head()
# Out:
#    Age Group  Gender Music Genre
# 0         20       0         Pop
# 1         39       1         Pop
# 2         22       1         Pop
# 3         40       1         Pop
# 4         40       0     Hip-Hop

# %%
df
# Out:
#     Age Group  Gender Music Genre
# 0          20       0         Pop
# 1          39       1         Pop
# 2          22       1         Pop
# 3          40       1         Pop
# 4          40       0     Hip-Hop
# 5          23       0     Hip-Hop
# 6          41       1     Hip-Hop
# 7          37       1       Trans
# 8          28       1       Trans
# 9          40       1       Trans
# 10         35       1        Jazz
# 11         27       1        Jazz
# 12         38       0        Jazz
# 13         34       1       Anime
# 14         32       0       Anime
# 15         39       0       Anime
# 16         23       0       Phonk
# 17         41       1       Phonk
# 18         33       1       Phonk
# 19         29       1        Trap
# 20         20       0        Trap
# 21         32       0        Jazz
# 22         31       0  Electronic
# 23         36       0     Country
# 24         21       0        Rock
# 25         39       0        Rock
# ...

# %%
while x<=29:
    df = df.drop(x, axis=0)
    x+=1

# %%
df
# Out:
#     Age Group  Gender Music Genre
# 0          20       0         Pop
# 1          39       1         Pop
# 2          22       1         Pop
# 3          40       1         Pop
# 4          40       0     Hip-Hop
# 5          23       0     Hip-Hop
# 6          41       1     Hip-Hop
# 7          37       1       Trans
# 8          28       1       Trans
# 9          40       1       Trans
# 10         35       1        Jazz
# 11         27       1        Jazz
# 12         38       0        Jazz
# 13         34       1       Anime
# 14         32       0       Anime
# 15         39       0       Anime
# 16         23       0       Phonk
# 17         41       1       Phonk
# 18         33       1       Phonk
# 19         29       1        Trap
# 20         20       0        Trap

# %%
df.drop(1, axis=0, inplace=True)

# %%
df.reset_index(drop=True, inplace = True)

# %%
df
# Out:
#     Age Group  Gender Music Genre
# 0          20       0         Pop
# 1          22       1         Pop
# 2          40       1         Pop
# 3          40       0     Hip-Hop
# 4          23       0     Hip-Hop
# 5          41       1     Hip-Hop
# 6          37       1       Trans
# 7          28       1       Trans
# 8          40       1       Trans
# 9          35       1        Jazz
# 10         27       1        Jazz
# 11         38       0        Jazz
# 12         34       1       Anime
# 13         32       0       Anime
# 14         39       0       Anime
# 15         23       0       Phonk
# 16         41       1       Phonk
# 17         33       1       Phonk
# 18         29       1        Trap
# 19         20       0        Trap

# %%
df.rename(columns={'Age Group': 'Age', 'Music Genre': 'Genre'}, inplace=True)

# %%
if df['Genre'] == 'Pop':
    for df['Genre'] == 'Pop'
        df['Age'] = df.loc[df['Genre']random.randint(20,25)
# elif df['Genre'] == 'Hip-Hop':
#     df['Age'] =random.randint(26,30)
# elif df['Genre'] == 'Trans':
#     df['Age'] =random.randint(31,35)
# elif df['Genre'] == 'Jazz':
#     df['Age'] =random.randint(36,40)
# elif df['Genre'] == 'Anime':
#     df['Age'] =random.randint(41,45)
# elif df['Genre'] == 'Phonk':
#     df['Age'] =random.randint(46,50)
# elif df['Genre'] == 'Trap':
#     df['Age'] =random.randint(51,55)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/m7/9y8yxtsj0g95rl866wh70mb80000gn/T/ipykernel_25507/2907206591.py in ?()
# ----> 1 if df['Genre'] == 'Pop':
#       2     df['Age'] =random.randint(20,25)
#       3 elif df['Genre'] == 'Hip-Hop':
#       4     df['Age'] =random.randint(26,30)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py in ?(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.loc[df['Genre'] == 'Pop'] = df.iloc[0,0]
# Out:
#    Age  Gender Genre
# 0   20       0   Pop
# 1   22       1   Pop
# 2   40       1   Pop

# %%
# for y in df:
#     if df.loc[df['Genre']=='Pop']:
#         for i in range(0,4):
    # df.loc[df['Genre'] == 'Pop', 'Age'] = random.randint(20,25)
            # df.iloc[i,0] = random.randint(20,25)
    # elif df.iloc[n,2]=='Hip-Hop':
    #     for i in range(4,7):
    #         df.iloc[i,0] = random.randint(25,30)
    # elif df.iloc[n,2]=='Trans':
    #     for i in range(7,10):
    #         df.iloc[i,0] = random.randint(30,35)
    # elif df.iloc[n,2]=='Jazz':
    #     for i in range(10,13):
    #         df.iloc[i,0] = random.randint(35,40)
    # elif df.iloc[n,2]=='Anime':
    #     for i in range(13,16):
    #         df.iloc[i,0] = random.randint(40,45)
    # elif df.iloc[n,2]=='Phonk':
    #     for i in range(16,19):
    #         df.iloc[i,0] = random.randint(45,50)
    # elif df.iloc[n,2]=='Trap':
    #     for i in range(19,21):
    #         df.iloc[i,0] = random.randint(50,55)

pop_indices = df[df['Genre'] == 'Pop'].index
for i in pop_indices:
    df.at[i, 'Age'] = random.randint(20, 25)

# %%
df.head()
# Out:
#    Age  Gender    Genre
# 0   21       0      Pop
# 1   22       1      Pop
# 2   23       1      Pop
# 3   40       0  Hip-Hop
# 4   23       0  Hip-Hop

# %%
pop_indices = df[df['Genre'] == 'Trap'].index
for i in pop_indices:
    df.at[i, 'Age'] = random.randint(51, 55)

# %%
df
# Out:
#     Age  Gender    Genre
# 0    21       0      Pop
# 1    22       1      Pop
# 2    23       1      Pop
# 3    27       0  Hip-Hop
# 4    28       0  Hip-Hop
# 5    29       1  Hip-Hop
# 6    34       1    Trans
# 7    33       1    Trans
# 8    34       1    Trans
# 9    38       1     Jazz
# 10   37       1     Jazz
# 11   40       0     Jazz
# 12   42       1    Anime
# 13   43       0    Anime
# 14   42       0    Anime
# 15   47       0    Phonk
# 16   50       1    Phonk
# 17   46       1    Phonk
# 18   54       1     Trap
# 19   54       0     Trap

# %%
df.at[2,'Age']
# Out:
# 23

# %%
X = df.drop('Genre', axis=1)

# %%
y = df['Genre']
y
# Out:
# 0         Pop
# 1         Pop
# 2         Pop
# 3     Hip-Hop
# 4     Hip-Hop
# 5     Hip-Hop
# 6       Trans
# 7       Trans
# 8       Trans
# 9        Jazz
# 10       Jazz
# 11       Jazz
# 12      Anime
# 13      Anime
# 14      Anime
# 15      Phonk
# 16      Phonk
# 17      Phonk
# 18       Trap
# 19       Trap
# Name: Genre, dtype: object

# %%
X
# Out:
#     Age  Gender
# 0    21       0
# 1    22       1
# 2    23       1
# 3    27       0
# 4    28       0
# 5    29       1
# 6    34       1
# 7    33       1
# 8    34       1
# 9    38       1
# 10   37       1
# 11   40       0
# 12   42       1
# 13   43       0
# 14   42       0
# 15   47       0
# 16   50       1
# 17   46       1
# 18   54       1
# 19   54       0

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()

# %%
model.fit (X, y)
predictions = model.predict ([ [21, 1], [22, 0] ])
predictions
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Pop', 'Pop'], dtype=object)

# %%
X.columns
# Out:
# Index(['Age', 'Gender'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
model = DecisionTreeClassifier()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model.fit (X_train, y_train)
predictions=model.predict(X_test)
score=accuracy_score(y_test, predictions)
score

# %%
import joblib

# %%
pip install joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# model = DecisionTreeClassifier()

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# model.fit (X_train, y_train)

joblib.dump (model, 'music-recommender.joblib')
# predictions=model.predict(X_test)
# score=accuracy_score(y_test, predictions)
# score
# Out:
# ['music-recommender.joblib']

# %%
joblib.load ('music-recommender.joblib')
predictions=model.predict([[23,0]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
predictions
# Out:
# array(['Pop'], dtype=object)

# %%
from sklearn import tree

# %%
tree.export_graphviz (model, out_file='music-recommender.dot', feature_names=['Age', 'Gender'], class_names=sorted(y.unique()), label='all', rounded=True, filled=True)
